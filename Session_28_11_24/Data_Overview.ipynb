# %% [markdown]
# # Seminar session Do. 28.11.2024
# ##### Andreas Wagner
#
#
#
# # Structure:
#
# 1. Parse data from .json into .csv file
# 2. Data-Structure
# 3. plotting basics

# %%
import pandas as pd
import plotly as py
import plotly.express as px
import json
import os

# %% [markdown]
# ## 1. Parsing data from .json into .csv file
# ### Basic pandas parsing
#
# Run the following line of code and examine what went wrong.
#
# !Hint: NaN equals the phrase Not a Number and indicates missing data.

# %%
# Load data from wue02.json
with open('wue02.json') as json_file:
    data = json.load(json_file)

# Convert the JSON data to a pandas dataframe
df = pd.DataFrame(data)

# Display the dataframe
print(df)
# Out:
#                                                              P07  P09  P11  \
# 1718266733014  {'location': {'locationID': '1718266928666', '...  NaN  NaN
# 1718267618450  {'location': {'locationID': '1718267853810', '...  NaN  NaN
# 1718268467154  {'tags': [{'tag': 'Ereignisreich', 'tagType': ...  NaN  NaN
# 1718269293446  {'location': {'locationID': '1718269488413', '...  NaN  NaN
# 1718270040934  {'tags': [{'tag': 'Ereignisreich', 'tagType': ...  NaN  NaN
# ...                                                          ...  ...  ...
# 1718273026070                                                NaN  NaN  NaN
# 1718275564692                                                NaN  NaN  NaN
# 1718277122119                                                NaN  NaN  NaN
# 1718277918503                                                NaN  NaN  NaN
# 1718278344068                                                NaN  NaN  NaN
#
#                P19  p01  p02  p03  p04  p05  p06  p13  p14  p15  p16  p17  \
# 1718266733014  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718267618450  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718268467154  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718269293446  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718270040934  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1718273026070  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718275564692  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718277122119  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718277918503  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1718278344068  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                              p18
# 1718266733014                                                NaN
# 1718267618450                                                NaN
# 1718268467154                                                NaN
# 1718269293446                                                NaN
# 1718270040934                                                NaN
# ...                                                          ...
# 1718273026070  {'location': {'locationID': '1718273640730', '...
# 1718275564692  {'tags': [{'tag': 'Eventful', 'tagType': 'numb...
# 1718277122119  {'tags': [{'tag': 'Eventful', 'tagType': 'numb...
# 1718277918503  {'tags': [{'tag': 'Eventful', 'tagType': 'numb...
# 1718278344068  {'media': [{'mediaID': 'p18/1718278344068/medi...
#
# [80 rows x 16 columns]

# %% [markdown]
# ### Better way to work with this json data?
#
# Have a quick think before looking at the following line of code:
#
# - what datatypes do you know that could be worked with?
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .

# %%
json_dict = {}

# creating a simple dictionary in the form of the json data: 

json_dict['P01'] = {
    'key01': 'value01',
    'key02': {
        'subKey0201': 'subValue0201',
    },
    "key03": [1, 2, 3]
}

# then we can refere to the different keys and values in the dictionary:

print(json_dict['P01']['key02']['subKey0201'])
# Out:
# subValue0201

# %% [markdown]
# ### JSON and Dictionaries
#
# - We begin again with loading the json file into a dictionary

# %%
with open("wue02.json", "r") as json_file:
    data = json.load(json_file)
    
data
# Out:
# {'P07': {'1718266733014': {'location': {'locationID': '1718266928666',
#     'lat': '49.800366',
#     'lon': '9.9323516'},
#    'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'}],
#    'media': [{'mediaID': 'P07/1718266733014/media/1718266733009.aac',
#      'lastModified': '2024-11-27T13:43:42.768Z',
#      'size': 72678},
#     {'mediaID': 'P07/1718266733014/media/1718266776456.aac',
#      'lastModified': '2024-11-27T13:43:44.535Z',
#      'size': 72678},
#     {'mediaID': 'P07/1718266733014/media/1718266884668.aac',
#      'lastModified': '2024-11-27T13:43:44.444Z',
#      'size': 72678},
#     {'mediaID': 'P07/1718266733014/media/1718266905336.jpg',
#      'lastModified': '2024-11-27T13:43:42.012Z',
#      'size': 5265418},
#     {'mediaID': 'P07/1718266733014/media/1718266913377.jpg',
#      'lastModified': '2024-11-27T13:43:44.235Z',
#      'size': 4260062},
#     {'mediaID': 'P07/1718266733014/media/1718266921444.jpg',
#      'lastModified': '2024-11-27T13:43:42.376Z',
#      'size': 5874750}]},
#   '1718267618450': {'location': {'locationID': '1718267853810',
#     'lat': '49.7954867',
#     'lon': '9.9297233'},
#    'tags': [{'tag': 'Ereignisreich',
#      'tagType': 'number',
#      'tagLabel2': 'Ereignislos',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Anregend',
#      'tagType': 'number',
#      'tagLabel2': 'Monoton',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Angenehm',
#      'tagType': 'number',
#      'tagLabel2': 'Unangenehm',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotisch',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Ängstlich',
#      'tagType': 'number',
#      'tagLabel2': 'Sicher',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Gestresst',
#      'tagType': 'number',
#      'tagLabel2': 'Entspannt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Bedrückt',
#      'tagType': 'number',
#      'tagLabel2': 'Unbeschwert',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Isoliert',
#      'tagType': 'number',
#      'tagLabel2': 'Verbunden',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Erschöpft',
#      'tagType': 'number',
#      'tagLabel2': 'Angeregt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'menschenleer',
#      'tagType': 'number',
#      'tagLabel2': 'menschenüberfüllt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'begehbar',
#      'tagType': 'number',
#      'tagLabel2': 'unzugänglich',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'zentral',
#      'tagType': 'number',
#      'tagLabel2': 'abgelegen',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'begrünt',
#      'tagType': 'number',
#      'tagLabel2': 'bebaut',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'sauber',
#      'tagType': 'number',
#      'tagLabel2': 'schmutzig',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'belebt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'entspannend',
#      'tagType': 'number',
#      'tagLabel2': 'aufwühlend',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'}],
#    'media': [{'mediaID': 'P07/1718267618450/media/1718267618446.aac',
#      'lastModified': '2024-11-27T13:43:49.463Z',
#      'size': 96561},
#     {'mediaID': 'P07/1718267618450/media/1718267698930.aac',
#      'lastModified': '2024-11-27T13:43:52.933Z',
#      'size': 96561},
#     {'mediaID': 'P07/1718267618450/media/1718267813072.aac',
#      'lastModified': '2024-11-27T13:43:53.373Z',
#      'size': 96561},
#     {'mediaID': 'P07/1718267618450/media/1718267828875.jpg',
#      'lastModified': '2024-11-27T13:43:53.160Z',
#      'size': 4273692},
#     {'mediaID': 'P07/1718267618450/media/1718267836964.jpg',
#      'lastModified': '2024-11-27T13:43:51.683Z',
#      'size': 4659824},
#     {'mediaID': 'P07/1718267618450/media/1718267846577.jpg',
#      'lastModified': '2024-11-27T13:43:53.004Z',
#      'size': 3472121}]},
#   '1718268467154': {'tags': [{'tag': 'Ereignisreich',
#      'tagType': 'number',
#      'tagLabel2': 'Ereignislos',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Anregend',
#      'tagType': 'number',
#      'tagLabel2': 'Monoton',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Angenehm',
#      'tagType': 'number',
#      'tagLabel2': 'Unangenehm',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotisch',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Ängstlich',
#      'tagType': 'number',
#      'tagLabel2': 'Sicher',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Gestresst',
#      'tagType': 'number',
#      'tagLabel2': 'Entspannt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Bedrückt',
#      'tagType': 'number',
#      'tagLabel2': 'Unbeschwert',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Isoliert',
#      'tagType': 'number',
#      'tagLabel2': 'Verbunden',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Erschöpft',
#      'tagType': 'number',
#      'tagLabel2': 'Angeregt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'menschenleer',
#      'tagType': 'number',
#      'tagLabel2': 'menschenüberfüllt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'begehbar',
#      'tagType': 'number',
#      'tagLabel2': 'unzugänglich',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'zentral',
#      'tagType': 'number',
#      'tagLabel2': 'abgelegen',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'begrünt',
#      'tagType': 'number',
#      'tagLabel2': 'bebaut',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'sauber',
#      'tagType': 'number',
#      'tagLabel2': 'schmutzig',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'belebt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'entspannend',
#      'tagType': 'number',
#      'tagLabel2': 'aufwühlend',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'}],
#    'media': [{'mediaID': 'P07/1718268467154/media/1718268467149.aac',
#      'lastModified': '2024-11-27T13:43:56.269Z',
#      'size': 115855},
#     {'mediaID': 'P07/1718268467154/media/1718268544815.aac',
#      'lastModified': '2024-11-27T13:43:56.641Z',
#      'size': 115855},
#     {'mediaID': 'P07/1718268467154/media/1718268610093.aac',
#      'lastModified': '2024-11-27T13:43:57.316Z',
#      'size': 115855},
#     {'mediaID': 'P07/1718268467154/media/1718268631834.jpg',
#      'lastModified': '2024-11-27T13:43:57.446Z',
#      'size': 4431749},
#     {'mediaID': 'P07/1718268467154/media/1718268641760.jpg',
#      'lastModified': '2024-11-27T13:43:55.980Z',
#      'size': 3383959},
#     {'mediaID': 'P07/1718268467154/media/1718268657255.jpg',
#      'lastModified': '2024-11-27T13:43:56.166Z',
#      'size': 1917902}],
#    'location': {'locationID': '1718268662450',
#     'lat': '49.79121',
#     'lon': '9.9317583'}},
#   '1718269293446': {'location': {'locationID': '1718269488413',
#     'lat': '49.795275',
#     'lon': '9.933345'},
#    'tags': [{'tag': 'Ereignisreich',
#      'tagType': 'number',
#      'tagLabel2': 'Ereignislos',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Anregend',
#      'tagType': 'number',
#      'tagLabel2': 'Monoton',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Angenehm',
#      'tagType': 'number',
#      'tagLabel2': 'Unangenehm',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotisch',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Ängstlich',
#      'tagType': 'number',
#      'tagLabel2': 'Sicher',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Gestresst',
#      'tagType': 'number',
#      'tagLabel2': 'Entspannt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Bedrückt',
#      'tagType': 'number',
#      'tagLabel2': 'Unbeschwert',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Isoliert',
#      'tagType': 'number',
#      'tagLabel2': 'Verbunden',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Erschöpft',
#      'tagType': 'number',
#      'tagLabel2': 'Angeregt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'menschenleer',
#      'tagType': 'number',
#      'tagLabel2': 'menschenüberfüllt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'begehbar',
#      'tagType': 'number',
#      'tagLabel2': 'unzugänglich',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'zentral',
#      'tagType': 'number',
#      'tagLabel2': 'abgelegen',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'begrünt',
#      'tagType': 'number',
#      'tagLabel2': 'bebaut',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'sauber',
#      'tagType': 'number',
#      'tagLabel2': 'schmutzig',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'belebt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'entspannend',
#      'tagType': 'number',
#      'tagLabel2': 'aufwühlend',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'}],
#    'media': [{'mediaID': 'P07/1718269293446/media/1718269293442.aac',
#      'lastModified': '2024-11-27T13:43:49.187Z',
#      'size': 105453},
#     {'mediaID': 'P07/1718269293446/media/1718269389539.aac',
#      'lastModified': '2024-11-27T13:43:46.570Z',
#      'size': 105453},
#     {'mediaID': 'P07/1718269293446/media/1718269450081.aac',
#      'lastModified': '2024-11-27T13:43:49.067Z',
#      'size': 105453},
#     {'mediaID': 'P07/1718269293446/media/1718269458566.jpg',
#      'lastModified': '2024-11-27T13:43:46.665Z',
#      'size': 3482731},
#     {'mediaID': 'P07/1718269293446/media/1718269475036.jpg',
#      'lastModified': '2024-11-27T13:43:47.781Z',
#      'size': 4458790},
#     {'mediaID': 'P07/1718269293446/media/1718269482704.jpg',
#      'lastModified': '2024-11-27T13:43:48.621Z',
#      'size': 4091511}]},
#   '1718270040934': {'tags': [{'tag': 'Ereignisreich',
#      'tagType': 'number',
#      'tagLabel2': 'Ereignislos',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Anregend',
#      'tagType': 'number',
#      'tagLabel2': 'Monoton',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Angenehm',
#      'tagType': 'number',
#      'tagLabel2': 'Unangenehm',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotisch',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Ängstlich',
#      'tagType': 'number',
#      'tagLabel2': 'Sicher',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Gestresst',
#      'tagType': 'number',
#      'tagLabel2': 'Entspannt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Bedrückt',
#      'tagType': 'number',
#      'tagLabel2': 'Unbeschwert',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Isoliert',
#      'tagType': 'number',
#      'tagLabel2': 'Verbunden',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Erschöpft',
#      'tagType': 'number',
#      'tagLabel2': 'Angeregt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'menschenleer',
#      'tagType': 'number',
#      'tagLabel2': 'menschenüberfüllt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'begehbar',
#      'tagType': 'number',
#      'tagLabel2': 'unzugänglich',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'zentral',
#      'tagType': 'number',
#      'tagLabel2': 'abgelegen',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'begrünt',
#      'tagType': 'number',
#      'tagLabel2': 'bebaut',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'sauber',
#      'tagType': 'number',
#      'tagLabel2': 'schmutzig',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'belebt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'entspannend',
#      'tagType': 'number',
#      'tagLabel2': 'aufwühlend',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'}],
#    'media': [{'mediaID': 'P07/1718270040934/media/1718270040930.aac',
#      'lastModified': '2024-11-27T13:44:00.545Z',
#      'size': 151113},
#     {'mediaID': 'P07/1718270040934/media/1718270139904.aac',
#      'lastModified': '2024-11-27T13:43:59.455Z',
#      'size': 151113},
#     {'mediaID': 'P07/1718270040934/media/1718270216190.aac',
#      'lastModified': '2024-11-27T13:43:59.261Z',
#      'size': 151113},
#     {'mediaID': 'P07/1718270040934/media/1718270224155.jpg',
#      'lastModified': '2024-11-27T13:43:59.294Z',
#      'size': 3275554},
#     {'mediaID': 'P07/1718270040934/media/1718270231787.jpg',
#      'lastModified': '2024-11-27T13:43:59.485Z',
#      'size': 3600592},
#     {'mediaID': 'P07/1718270040934/media/1718270275148.jpg',
#      'lastModified': '2024-11-27T13:43:59.635Z',
#      'size': 2644719}],
#    'location': {'locationID': '1718270282109',
#     'lat': '49.7963654',
#     'lon': '9.9351056'}}},
#  'P09': {'1718270244840': {'media': [{'mediaID': 'P09/1718270244840/media/1718270244836.aac',
#      'lastModified': '2024-11-27T13:43:28.398Z',
#      'size': 10019},
#     {'mediaID': 'P09/1718270244840/media/1718270278229.aac',
#      'lastModified': '2024-11-27T13:43:28.398Z',
#      'size': 30746},
#     {'mediaID': 'P09/1718270244840/media/1718270304913.aac',
#      'lastModified': '2024-11-27T13:43:28.382Z',
#      'size': 31995},
#     {'mediaID': 'P09/1718270244840/media/1718270339733.jpg',
#      'lastModified': '2024-11-27T13:43:28.418Z',
#      'size': 3030458},
#     {'mediaID': 'P09/1718270244840/media/1718270374436.jpg',
#      'lastModified': '2024-11-27T13:43:28.609Z',
#      'size': 2854509},
#     {'mediaID': 'P09/1718270244840/media/1718270386180.jpg',
#      'lastModified': '2024-11-27T13:43:28.246Z',
#      'size': 3858367}],
#    'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'}],
#    'location': {'locationID': '1718270388341',
#     'lat': '49.7996317',
#     'lon': '9.9335133'}},
#   '1718271504316': {'media': [{'mediaID': 'P09/1718271504316/media/1718271504312.aac',
#      'lastModified': '2024-11-27T13:43:30.506Z',
#      'size': 8125},
#     {'mediaID': 'P09/1718271504316/media/1718271526276.aac',
#      'lastModified': '2024-11-27T13:43:30.258Z',
#      'size': 30034},
#     {'mediaID': 'P09/1718271504316/media/1718271549151.aac',
#      'lastModified': '2024-11-27T13:43:29.271Z',
#      'size': 36290},
#     {'mediaID': 'P09/1718271504316/media/1718271576552.jpg',
#      'lastModified': '2024-11-27T13:43:30.258Z',
#      'size': 2315064},
#     {'mediaID': 'P09/1718271504316/media/1718271586933.jpg',
#      'lastModified': '2024-11-27T13:43:30.062Z',
#      'size': 3131830},
#     {'mediaID': 'P09/1718271504316/media/1718271594273.jpg',
#      'lastModified': '2024-11-27T13:43:30.276Z',
#      'size': 2466107}],
#    'location': {'locationID': '1718271602679',
#     'lat': '49.795545',
#     'lon': '9.930225'},
#    'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'}],
#    'text': '\n'},
#   '1718272521723': {'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'}],
#    'location': {'locationID': '1718272632958',
#     'lat': '49.7913533',
#     'lon': '9.93108'},
#    'media': [{'mediaID': 'P09/1718272521723/media/1718272521716.aac',
#      'lastModified': '2024-11-27T13:43:35.207Z',
#      'size': 9341},
#     {'mediaID': 'P09/1718272521723/media/1718272553775.aac',
#      'lastModified': '2024-11-27T13:43:33.944Z',
#      'size': 39770},
#     {'mediaID': 'P09/1718272521723/media/1718272582944.aac',
#      'lastModified': '2024-11-27T13:43:33.628Z',
#      'size': 51920},
#     {'mediaID': 'P09/1718272521723/media/1718272615619.jpg',
#      'lastModified': '2024-11-27T13:43:35.313Z',
#      'size': 2589816},
#     {'mediaID': 'P09/1718272521723/media/1718272623492.jpg',
#      'lastModified': '2024-11-27T13:43:34.369Z',
#      'size': 2830626},
#     {'mediaID': 'P09/1718272521723/media/1718272631217.jpg',
#      'lastModified': '2024-11-27T13:43:33.841Z',
#      'size': 3206083}]},
#   '1718273580862': {'media': [{'mediaID': 'P09/1718273580862/media/1718273580856.aac',
#      'lastModified': '2024-11-27T13:43:36.013Z',
#      'size': 8958},
#     {'mediaID': 'P09/1718273580862/media/1718273603182.aac',
#      'lastModified': '2024-11-27T13:43:37.375Z',
#      'size': 25864},
#     {'mediaID': 'P09/1718273580862/media/1718273646563.aac',
#      'lastModified': '2024-11-27T13:43:37.371Z',
#      'size': 34080},
#     {'mediaID': 'P09/1718273580862/media/1718273655331.jpg',
#      'lastModified': '2024-11-27T13:43:35.852Z',
#      'size': 3226761},
#     {'mediaID': 'P09/1718273580862/media/1718273665637.jpg',
#      'lastModified': '2024-11-27T13:43:36.937Z',
#      'size': 2543550},
#     {'mediaID': 'P09/1718273580862/media/1718273682043.jpg',
#      'lastModified': '2024-11-27T13:43:36.958Z',
#      'size': 2745787}],
#    'location': {'locationID': '1718273684814',
#     'lat': '49.7950917',
#     'lon': '9.9340167'},
#    'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'}]},
#   '1718274113593': {'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'}],
#    'location': {'locationID': '1718274240779',
#     'lat': '49.79619',
#     'lon': '9.9352333'},
#    'media': [{'mediaID': 'P09/1718274113593/media/1718274113589.aac',
#      'lastModified': '2024-11-27T13:43:39.510Z',
#      'size': 10022},
#     {'mediaID': 'P09/1718274113593/media/1718274143850.aac',
#      'lastModified': '2024-11-27T13:43:40.359Z',
#      'size': 32064},
#     {'mediaID': 'P09/1718274113593/media/1718274203695.aac',
#      'lastModified': '2024-11-27T13:43:39.511Z',
#      'size': 60251},
#     {'mediaID': 'P09/1718274113593/media/1718274217642.jpg',
#      'lastModified': '2024-11-27T13:43:39.091Z',
#      'size': 4747999},
#     {'mediaID': 'P09/1718274113593/media/1718274226392.jpg',
#      'lastModified': '2024-11-27T13:43:40.392Z',
#      'size': 3829392},
#     {'mediaID': 'P09/1718274113593/media/1718274238587.jpg',
#      'lastModified': '2024-11-27T13:43:40.694Z',
#      'size': 2486353}]}},
#  'P11': {'1718269063538': {'location': {'locationID': '1718269478095',
#     'lat': '49.8003079',
#     'lon': '9.9325363'},
#    'tags': [{'tag': 'Ereignisreich',
#      'tagType': 'number',
#      'tagLabel2': 'Ereignislos',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Anregend',
#      'tagType': 'number',
#      'tagLabel2': 'Monoton',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Angenehm',
#      'tagType': 'number',
#      'tagLabel2': 'Unangenehm',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotisch',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Ängstlich',
#      'tagType': 'number',
#      'tagLabel2': 'Sicher',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Gestresst',
#      'tagType': 'number',
#      'tagLabel2': 'Entspannt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Bedrückt',
#      'tagType': 'number',
#      'tagLabel2': 'Unbeschwert',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Isoliert',
#      'tagType': 'number',
#      'tagLabel2': 'Verbunden',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Erschöpft',
#      'tagType': 'number',
#      'tagLabel2': 'Angeregt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'menschenleer',
#      'tagType': 'number',
#      'tagLabel2': 'menschenüberfüllt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'begehbar',
#      'tagType': 'number',
#      'tagLabel2': 'unzugänglich',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'zentral',
#      'tagType': 'number',
#      'tagLabel2': 'abgelegen',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'begrünt',
#      'tagType': 'number',
#      'tagLabel2': 'bebaut',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'sauber',
#      'tagType': 'number',
#      'tagLabel2': 'schmutzig',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'belebt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'entspannend',
#      'tagType': 'number',
#      'tagLabel2': 'aufwühlend',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Ereignisreich',
#      'tagType': 'number',
#      'tagLabel2': 'Ereignislos',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Anregend',
#      'tagType': 'number',
#      'tagLabel2': 'Monoton',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Angenehm',
#      'tagType': 'number',
#      'tagLabel2': 'Unangenehm',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotisch',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'Ängstlich',
#      'tagType': 'number',
#      'tagLabel2': 'Sicher',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Gestresst',
#      'tagType': 'number',
#      'tagLabel2': 'Entspannt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Bedrückt',
#      'tagType': 'number',
#      'tagLabel2': 'Unbeschwert',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Isoliert',
#      'tagType': 'number',
#      'tagLabel2': 'Verbunden',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Erschöpft',
#      'tagType': 'number',
#      'tagLabel2': 'Angeregt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'menschenleer',
#      'tagType': 'number',
#      'tagLabel2': 'menschenüberfüllt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'begehbar',
#      'tagType': 'number',
#      'tagLabel2': 'unzugänglich',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'zentral',
#      'tagType': 'number',
#      'tagLabel2': 'abgelegen',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'begrünt',
#      'tagType': 'number',
#      'tagLabel2': 'bebaut',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'sauber',
#      'tagType': 'number',
#      'tagLabel2': 'schmutzig',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'ruhig',
#      'tagType': 'number',
#      'tagLabel2': 'belebt',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'entspannend',
#      'tagType': 'number',
#      'tagLabel2': 'aufwühlend',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'}],
#    'media': [{'mediaID': 'P11/1718269063538/media/1718269063533.aac',
#      'lastModified': '2024-11-27T13:30:49.809Z',
#      'size': 10273},
#     {'mediaID': 'P11/1718269063538/media/1718269287555.aac',
#      'lastModified': '2024-11-27T13:30:49.518Z',
#      'size': 95448},
#     {'mediaID': 'P11/1718269063538/media/1718269428432.aac',
#      'lastModified': '2024-11-27T13:30:49.392Z',
#      'size': 285304},
#     {'mediaID': 'P11/1718269063538/media/1718269442662.jpg',
# ...
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'}]},
#   '1718275564692': {'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'}],
#    'media': [{'mediaID': 'p18/1718275564692/media/1718275564688.aac',
#      'lastModified': '2024-11-27T13:27:26.898Z',
#      'size': 10312},
#     {'mediaID': 'p18/1718275564692/media/1718275706344.aac',
#      'lastModified': '2024-11-27T13:27:23.881Z',
#      'size': 129549},
#     {'mediaID': 'p18/1718275564692/media/1718275816279.aac',
#      'lastModified': '2024-11-27T13:27:30.042Z',
#      'size': 164913},
#     {'mediaID': 'p18/1718275564692/media/1718275835795.jpg',
#      'lastModified': '2024-11-27T13:27:23.597Z',
#      'size': 5132623},
#     {'mediaID': 'p18/1718275564692/media/1718275850012.jpg',
#      'lastModified': '2024-11-27T13:27:26.728Z',
#      'size': 4090840},
#     {'mediaID': 'p18/1718275564692/media/1718275876352.jpg',
#      'lastModified': '2024-11-27T13:27:23.958Z',
#      'size': 3073085}],
#    'location': {'locationID': '1718275880199',
#     'lat': '49.7950566',
#     'lon': '9.9292527'}},
#   '1718277122119': {'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 1.0'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'}],
#    'location': {'locationID': '1718277646651',
#     'lat': '49.7932106',
#     'lon': '9.9331436'},
#    'media': [{'mediaID': 'p18/1718277122119/media/1718277122115.aac',
#      'lastModified': '2024-11-27T13:27:16.565Z',
#      'size': 10303},
#     {'mediaID': 'p18/1718277122119/media/1718277252848.aac',
#      'lastModified': '2024-11-27T13:27:17.417Z',
#      'size': 175298},
#     {'mediaID': 'p18/1718277122119/media/1718277331213.aac',
#      'lastModified': '2024-11-27T13:27:17.037Z',
#      'size': 126688},
#     {'mediaID': 'p18/1718277122119/media/1718277343049.jpg',
#      'lastModified': '2024-11-27T13:27:17.200Z',
#      'size': 3749208},
#     {'mediaID': 'p18/1718277122119/media/1718277353732.jpg',
#      'lastModified': '2024-11-27T13:27:16.400Z',
#      'size': 1929358},
#     {'mediaID': 'p18/1718277122119/media/1718277367972.jpg',
#      'lastModified': '2024-11-27T13:27:16.859Z',
#      'size': 2253522}]},
#   '1718277918503': {'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'}],
#    'media': [{'mediaID': 'p18/1718277918503/media/1718277918499.aac',
#      'lastModified': '2024-11-27T13:27:01.839Z',
#      'size': 10315},
#     {'mediaID': 'p18/1718277918503/media/1718278015283.aac',
#      'lastModified': '2024-11-27T13:27:01.960Z',
#      'size': 143934},
#     {'mediaID': 'p18/1718277918503/media/1718278089042.aac',
#      'lastModified': '2024-11-27T13:27:04.951Z',
#      'size': 136957},
#     {'mediaID': 'p18/1718277918503/media/1718278100697.jpg',
#      'lastModified': '2024-11-27T13:27:01.730Z',
#      'size': 1898280},
#     {'mediaID': 'p18/1718277918503/media/1718278107879.jpg',
#      'lastModified': '2024-11-27T13:27:00.098Z',
#      'size': 2899891},
#     {'mediaID': 'p18/1718277918503/media/1718278116704.jpg',
#      'lastModified': '2024-11-27T13:27:03.272Z',
#      'size': 2403504}],
#    'location': {'locationID': '1718278120051',
#     'lat': '49.7954101',
#     'lon': '9.9331912'}},
#   '1718278344068': {'media': [{'mediaID': 'p18/1718278344068/media/1718278344064.aac',
#      'lastModified': '2024-11-27T13:27:10.812Z',
#      'size': 10303},
#     {'mediaID': 'p18/1718278344068/media/1718278462140.aac',
#      'lastModified': '2024-11-27T13:27:08.457Z',
#      'size': 137782},
#     {'mediaID': 'p18/1718278344068/media/1718278551889.aac',
#      'lastModified': '2024-11-27T13:27:10.506Z',
#      'size': 675},
#     {'mediaID': 'p18/1718278344068/media/1718278570887.jpg',
#      'lastModified': '2024-11-27T13:27:10.666Z',
#      'size': 2151720},
#     {'mediaID': 'p18/1718278344068/media/1718278582950.jpg',
#      'lastModified': '2024-11-27T13:27:08.754Z',
#      'size': 2353060},
#     {'mediaID': 'p18/1718278344068/media/1718278643246.jpg',
#      'lastModified': '2024-11-27T13:27:10.276Z',
#      'size': 2919635}],
#    'location': {'locationID': '1718278645744',
#     'lat': '49.796784',
#     'lon': '9.9355711'},
#    'tags': [{'tag': 'Eventful',
#      'tagType': 'number',
#      'tagLabel2': 'Uneventful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Exciting',
#      'tagType': 'number',
#      'tagLabel2': 'Monotonous',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Pleasant',
#      'tagType': 'number',
#      'tagLabel2': 'Unpleasant',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Calm',
#      'tagType': 'number',
#      'tagLabel2': 'Chaotic',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Anxious',
#      'tagType': 'number',
#      'tagLabel2': 'Safe',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Stressed',
#      'tagType': 'number',
#      'tagLabel2': 'Relaxed',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 2.0'},
#     {'tag': 'Depressed',
#      'tagType': 'number',
#      'tagLabel2': 'Cheerful',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Detached',
#      'tagType': 'number',
#      'tagLabel2': 'Attached',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'Exhausted',
#      'tagType': 'number',
#      'tagLabel2': 'Excited',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'uncrowded ',
#      'tagType': 'number',
#      'tagLabel2': 'crowded',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3.0'},
#     {'tag': 'accessible',
#      'tagType': 'number',
#      'tagLabel2': 'unaccessible',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'central',
#      'tagType': 'number',
#      'tagLabel2': 'remote',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 3'},
#     {'tag': 'green ',
#      'tagType': 'number',
#      'tagLabel2': 'built-up',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 5.0'},
#     {'tag': 'clean',
#      'tagType': 'number',
#      'tagLabel2': 'polluted',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'quiet',
#      'tagType': 'number',
#      'tagLabel2': 'busy',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'},
#     {'tag': 'relaxing',
#      'tagType': 'number',
#      'tagLabel2': 'disturbing',
#      'tagMin': ' 1',
#      'tagMax': ' 5',
#      'tagStep': ' 1',
#      'tagValue': ' 4.0'}]}}}

# %% [markdown]
# ### Parse into Dataframe
#
# - for easy use we have to parse it into a dataframe
# - the structure of the dataframe has to be as given
#
# [personID, observationID, lat, lon, mediaPath, tagValue, tagLabel1, tagLabel2]
#
# - some additional columns for advanced use will be added

# %%
df = pd.DataFrame(columns=['id','observationID','personID','lat','lon','media',])

# just import the helper json; config questionaire
with open("config_questionaire.json", "r") as config_json:
    config = json.load(config_json)

for person in data:
    for observation in data[person]:
        for media in data[person][observation]['media']:
            # we add the media to the dataframe
            id = len(df)
            df.loc[id, 'id'] = id
            df.loc[id, 'observationID'] = observation
            df.loc[id, 'personID'] = person
            df.loc[id, 'lat'] = data[person][observation]['location']['lat']
            df.loc[id, 'lon'] = data[person][observation]['location']['lon']
            df.loc[id, 'media'] = media['mediaID']
            # we add the tags to the dataframe
            for tag in data[person][observation]['tags']:
                # if there is already a column for this specific tag, we add the value to the column. For identifying the tag we use the "tag" and the "tagLabel2" values. if they are in german, we map them to their english counterparts
                tag_column = f'{tag["tag"]}_{tag["tagLabel2"]}'
                for item in config['questionaire']:
                    if item['label1']['de'] == tag['tag'] and item['label2']['de'] == tag['tagLabel2']:
                        tag_column = f'{item["label1"]["en"]}_{item["label2"]["en"]}'
                if tag_column not in df.columns:
                    df[tag_column] = None
                df.loc[id, tag_column] = int(float(tag['tagValue']))
df
# Out:
#       id  observationID personID        lat        lon  \
# 0      0  1718266733014      P07  49.800366  9.9323516
# 1      1  1718266733014      P07  49.800366  9.9323516
# 2      2  1718266733014      P07  49.800366  9.9323516
# 3      3  1718266733014      P07  49.800366  9.9323516
# 4      4  1718266733014      P07  49.800366  9.9323516
# ..   ...            ...      ...        ...        ...
# 456  456  1718278344068      p18  49.796784  9.9355711
# 457  457  1718278344068      p18  49.796784  9.9355711
# 458  458  1718278344068      p18  49.796784  9.9355711
# 459  459  1718278344068      p18  49.796784  9.9355711
# 460  460  1718278344068      p18  49.796784  9.9355711
#
#                                          media Eventful_Uneventful  \
# 0    P07/1718266733014/media/1718266733009.aac                   1
# 1    P07/1718266733014/media/1718266776456.aac                   1
# 2    P07/1718266733014/media/1718266884668.aac                   1
# 3    P07/1718266733014/media/1718266905336.jpg                   1
# 4    P07/1718266733014/media/1718266913377.jpg                   1
# ..                                         ...                 ...
# 456  p18/1718278344068/media/1718278462140.aac                   2
# 457  p18/1718278344068/media/1718278551889.aac                   2
# 458  p18/1718278344068/media/1718278570887.jpg                   2
# 459  p18/1718278344068/media/1718278582950.jpg                   2
# 460  p18/1718278344068/media/1718278643246.jpg                   2
#
#     Exciting_Monotonous Pleasant_Unpleasant Calm_Chaotic  ...  \
# 0                     5                   5            5  ...
# 1                     5                   5            5  ...
# 2                     5                   5            5  ...
# 3                     5                   5            5  ...
# 4                     5                   5            5  ...
# ..                  ...                 ...          ...  ...
# 456                   2                   2            4  ...
# 457                   2                   2            4  ...
# 458                   2                   2            4  ...
# 459                   2                   2            4  ...
# 460                   2                   2            4  ...
#
#     Depressed_Cheerful Detached_Attached Exhausted_Excited uncrowded _crowded  \
# 0                    2                 1                 1                  2
# 1                    2                 1                 1                  2
# 2                    2                 1                 1                  2
# 3                    2                 1                 1                  2
# 4                    2                 1                 1                  2
# ..                 ...               ...               ...                ...
# 456                  4                 4                 4                  3
# 457                  4                 4                 4                  3
# 458                  4                 4                 4                  3
# 459                  4                 4                 4                  3
# 460                  4                 4                 4                  3
#
#     accessible_unaccessible central_remote green _built-up clean_polluted  \
# 0                         5              3               2              5
# 1                         5              3               2              5
# 2                         5              3               2              5
# 3                         5              3               2              5
# 4                         5              3               2              5
# ..                      ...            ...             ...            ...
# 456                       3              3               5              4
# 457                       3              3               5              4
# 458                       3              3               5              4
# 459                       3              3               5              4
# 460                       3              3               5              4
#
#     quiet_busy relaxing_disturbing
# 0            4                   5
# 1            4                   5
# 2            4                   5
# 3            4                   5
# 4            4                   5
# ..         ...                 ...
# 456          4                   4
# 457          4                   4
# 458          4                   4
# 459          4                   4
# 460          4                   4
#
# [461 rows x 22 columns]

# %% [markdown]
# ### Adding important infromation we can retrieve from the ID and the media Path
#
# - timestamp from observationID
# - type from file ending of mediaPath

# %%
df['mediaType'] = df['media'].apply(lambda x: "Image" if x.endswith('.jpg') else "Audio")

# %%
import datetime
# the datetime is in milliseconds from epoch 
df['timestamp'] = df['observationID'].apply(lambda x: datetime.datetime.fromtimestamp(int(x)/1000))

# %%
df.to_csv('data.csv', index=False)

# %% [markdown]
# ## Adding transcriptions to the audio files (If provided)

# %%
df['transcription'] = None
for element in os.listdir("transcriptionresults_p"):
    if element.endswith('.txt'):
        fileName = element.split('.')[0]
        with open(f'transcriptionresults_p/{element}', 'r') as file:
            transcription = file.read()
        for index, row in df.iterrows():
            if row['media'].split('/')[-1].split('.')[0] == fileName:
                df.loc[index, 'transcription'] = transcription
df
# Out:
#       id  observationID personID        lat        lon  \
# 0      0  1718266733014      P07  49.800366  9.9323516
# 1      1  1718266733014      P07  49.800366  9.9323516
# 2      2  1718266733014      P07  49.800366  9.9323516
# 3      3  1718266733014      P07  49.800366  9.9323516
# 4      4  1718266733014      P07  49.800366  9.9323516
# ..   ...            ...      ...        ...        ...
# 456  456  1718278344068      p18  49.796784  9.9355711
# 457  457  1718278344068      p18  49.796784  9.9355711
# 458  458  1718278344068      p18  49.796784  9.9355711
# 459  459  1718278344068      p18  49.796784  9.9355711
# 460  460  1718278344068      p18  49.796784  9.9355711
#
#                                          media Eventful_Uneventful  \
# 0    P07/1718266733014/media/1718266733009.aac                   1
# 1    P07/1718266733014/media/1718266776456.aac                   1
# 2    P07/1718266733014/media/1718266884668.aac                   1
# 3    P07/1718266733014/media/1718266905336.jpg                   1
# 4    P07/1718266733014/media/1718266913377.jpg                   1
# ..                                         ...                 ...
# 456  p18/1718278344068/media/1718278462140.aac                   2
# 457  p18/1718278344068/media/1718278551889.aac                   2
# 458  p18/1718278344068/media/1718278570887.jpg                   2
# 459  p18/1718278344068/media/1718278582950.jpg                   2
# 460  p18/1718278344068/media/1718278643246.jpg                   2
#
#     Exciting_Monotonous Pleasant_Unpleasant Calm_Chaotic  ...  \
# 0                     5                   5            5  ...
# 1                     5                   5            5  ...
# 2                     5                   5            5  ...
# 3                     5                   5            5  ...
# 4                     5                   5            5  ...
# ..                  ...                 ...          ...  ...
# 456                   2                   2            4  ...
# 457                   2                   2            4  ...
# 458                   2                   2            4  ...
# 459                   2                   2            4  ...
# 460                   2                   2            4  ...
#
#     uncrowded _crowded accessible_unaccessible central_remote green _built-up  \
# 0                    2                       5              3               2
# 1                    2                       5              3               2
# 2                    2                       5              3               2
# 3                    2                       5              3               2
# 4                    2                       5              3               2
# ..                 ...                     ...            ...             ...
# 456                  3                       3              3               5
# 457                  3                       3              3               5
# 458                  3                       3              3               5
# 459                  3                       3              3               5
# 460                  3                       3              3               5
#
#     clean_polluted quiet_busy relaxing_disturbing mediaType  \
# 0                5          4                   5     Audio
# 1                5          4                   5     Audio
# 2                5          4                   5     Audio
# 3                5          4                   5     Image
# 4                5          4                   5     Image
# ..             ...        ...                 ...       ...
# 456              4          4                   4     Audio
# 457              4          4                   4     Audio
# 458              4          4                   4     Image
# 459              4          4                   4     Image
# 460              4          4                   4     Image
#
#                   timestamp                                      transcription
# 0   2024-06-13 10:18:53.014   Ja gut, okay, nochmal neu. Also ich fühle mic...
# 1   2024-06-13 10:18:53.014   Ja gut, okay, nochmal neu. Also ich fühle mic...
# 2   2024-06-13 10:18:53.014   Ja gut, okay, nochmal neu. Also ich fühle mic...
# 3   2024-06-13 10:18:53.014                                               None
# 4   2024-06-13 10:18:53.014                                               None
# ..                      ...                                                ...
# 456 2024-06-13 13:32:24.068   Okay, I am currently walking around the Tross...
# 457 2024-06-13 13:32:24.068                                               None
# 458 2024-06-13 13:32:24.068                                               None
# 459 2024-06-13 13:32:24.068                                               None
# 460 2024-06-13 13:32:24.068                                               None
#
# [461 rows x 25 columns]

# %%
df.to_csv('data.csv', index=False)

# %% [markdown]
# ## Basic Plots of the dataframe
#
# ### single point one tag value on a scale from 1 to 5 (Likert basic)

# %%
fig = px.scatter(df, x='Eventful_Uneventful', y="personID", color='observationID')

fig.show()
